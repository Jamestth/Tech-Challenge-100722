# %%
import requests
import pandas as pd

# %%
endpoint = "https://api.covid19api.com/country/singapore/status/confirmed"

# Time range not a necessary parameter. Without indicating, all data is extracted. 
# #"2020-03-01T00:00:00Z"
# data_postfix = "T00:00:00Z"
# start_date = "2020-03-01"
# end_date = "2022-07-9"
# params = {"from": start_date + data_postfix, "to": end_date + data_postfix }
req = requests.get(endpoint)#, params=params)

# %%
# Convert to df
df = pd.DataFrame(req.json())
df
# Out:
#        Country CountryCode Province City CityCode   Lat     Lon    Cases  \
# 0    Singapore          SG                         1.35  103.82        0
# 1    Singapore          SG                         1.35  103.82        1
# 2    Singapore          SG                         1.35  103.82        3
# 3    Singapore          SG                         1.35  103.82        3
# 4    Singapore          SG                         1.35  103.82        4
# ..         ...         ...      ...  ...      ...   ...     ...      ...
# 895  Singapore          SG                         1.35  103.82  1485964
# 896  Singapore          SG                         1.35  103.82  1495953
# 897  Singapore          SG                         1.35  103.82  1505938
# 898  Singapore          SG                         1.35  103.82  1515222
# 899  Singapore          SG                         1.35  103.82  1515222
#
#         Status                  Date
# 0    confirmed  2020-01-22T00:00:00Z
# ...

# %%
# Save API_data
df.to_csv("API_data.csv", index = False)
